# %%
import os

import pandas as pd
import numpy as np
import scanpy as sc 
import anndata as ann
import seaborn as sns

# %%
# Change to Iniq working dir
os.chdir("/scratch/gobi2/hmaan/Documents/Iniquitate")

# %%
# Load data on downsampling summaries 
os.chdir("results/downsample_summaries/")
ds_summary_files = os.listdir()
summaries_read = []
for f in ds_summary_files:
    summaries_read.append(pd.read_csv(f, sep = "\t"))
summaries_concat = pd.concat(summaries_read)

# %%
# Grep only those datasets that were used in the lowcap setup
summaries_concat_lowcap = summaries_concat[
    (summaries_concat.Dataset.isin([
        "pbmc_2_batch",
        "pbmc_4_batch",
        "mouse_hindbrain_6_batch",
        "peng_pdac_8_batch"
    ])) &
    (summaries_concat.Replicate <= 4)
]

# %%
# Load data on clustering summaries
os.chdir("../clustering_summaries/")
ds_summary_files = os.listdir()
summaries_read = []
for f in ds_summary_files:
    summaries_read.append(pd.read_csv(f, sep = "\t"))
summaries_concat = pd.concat(summaries_read)

# %%
# Out:
#                     Dataset Batches downsampled  \
# 0              pbmc_4_batch                   3
# 1              pbmc_4_batch                   3
# 2              pbmc_4_batch                   3
# 0   mouse_hindbrain_6_batch                   1
# 1   mouse_hindbrain_6_batch                   1
# ..                      ...                 ...
# 1         peng_pdac_8_batch                   6
# 2         peng_pdac_8_batch                   6
# 3         peng_pdac_8_batch                   6
# 4         peng_pdac_8_batch                   6
# 5         peng_pdac_8_batch                   6
#
#    Number of celltypes downsampled  Proportion downsampled  \
# 0                                1                     0.5
# 1                                1                     0.5
# 2                                1                     0.5
# 0                                3                     0.0
# 1                                3                     0.0
# ..                             ...                     ...
# 1                                1                     0.0
# 2                                1                     0.0
# 3                                1                     0.0
# 4                                1                     0.0
# 5                                1                     0.0
#
#              Batch label                     Downsampled celltypes  Replicate
# 0               CEL-Seq2                                    B cell          3
# 1               Seq-Well                               CD4+ T cell          3
# 2      10x Chromium (v3)                       Natural killer cell          3
# 0   mdt_dev_E10_sce27998  Erythrocytes and erythrocyte progenitors          1
# 1   mdt_dev_E10_sce27998                            VZ progenitors          1
# ..                   ...                                       ...        ...
# 1              CRR034507                                   Th cell          4
# 2              CRR034513                        Myeloid/Macrophage          4
# 3              CRR034505                                   Th cell          4
# 4              CRR034503                            Endocrine cell          4
# 5              CRR034517                                    B cell          4
#
# [6302 rows x 7 columns]

# %%
np.unique(summaries_concat_lowcap["Replicate"], return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([1271, 1278, 1255, 1241, 1257]))
